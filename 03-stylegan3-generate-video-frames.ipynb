# %% [markdown]
# # StyleGAN3 from NVIDIA
#
# **Notes**
# * To see the original code from NVIDIA [Check here](https://github.com/NVlabs/stylegan3)
# * We are using a pretrained model and fine-tuning on top of it.

# %% [markdown]
# # Setup

# %% [markdown]
# # Generate images

# %%
import torch
import pickle
from pathlib import Path

model_path = '/Users/ted/dev/stylegan3/00022-stylegan3-r-240523_01-rose01-YFlips-6min-gpus1-batch8-gamma6.6/network-snapshot-000036.pkl'
outdir = '/Volumes/2024-May-Ted-Moore/videos/rose/stylegan/240525_02-rose01-blobs-interpolated-cos-pkl=36'

Path(outdir).mkdir()

# %%
import random

seeds = list(range(1000,1015))
random.shuffle(seeds)

seeds.append(seeds[0])

print(seeds)
print(len(seeds))
# Out:
# [1002, 1004, 1012, 1006, 1010, 1005, 1000, 1013, 1001, 1011, 1014, 1003, 1007, 1008, 1009, 1002]
# 16

# %%
import PIL.Image
from IPython.display import Image
import matplotlib.pyplot as plt
import IPython.display

"""Generate images using pretrained network pickle."""

import os
import re
from typing import List, Optional, Tuple, Union

import click
import dnnlib
import numpy as np
import PIL.Image
import torch

import legacy

device = torch.device('mps')
with open(model_path, 'rb') as f:
    G = pickle.load(f)['G_ema'].to(device)  # torch.nn.Module

#----------------------------------------------------------------------------

def parse_range(s: Union[str, List]) -> List[int]:
    '''Parse a comma separated list of numbers or ranges and return a list of ints.
    Example: '1,2,5-10' returns [1, 2, 5, 6, 7]
    '''
    if isinstance(s, list): return s
    ranges = []
    range_re = re.compile(r'^(\d+)-(\d+)$')
    for p in s.split(','):
        m = range_re.match(p)
        if m:
            ranges.extend(range(int(m.group(1)), int(m.group(2))+1))
        else:
            ranges.append(int(p))
    return ranges

#----------------------------------------------------------------------------

def parse_vec2(s: Union[str, Tuple[float, float]]) -> Tuple[float, float]:
    '''Parse a floating point 2-vector of syntax 'a,b'.
    Example:
        '0,1' returns (0,1)
    '''
    if isinstance(s, tuple): return s
    parts = s.split(',')
    if len(parts) == 2:
        return (float(parts[0]), float(parts[1]))
    raise ValueError(f'cannot parse 2-vector {s}')

#----------------------------------------------------------------------------

def make_transform(translate: Tuple[float,float], angle: float):
    m = np.eye(3)
    s = np.sin(angle/360.0*np.pi*2)
    c = np.cos(angle/360.0*np.pi*2)
    m[0][0] = c
    m[0][1] = s
    m[0][2] = translate[0]
    m[1][0] = -s
    m[1][1] = c
    m[1][2] = translate[1]
    return m

#----------------------------------------------------------------------------

# @click.command()
# @click.option('--network', 'network_pkl', help='Network pickle filename', required=True)
# @click.option('--seeds', type=parse_range, help='List of random seeds (e.g., \'0,1,4-6\')', required=True)
# @click.option('--trunc', 'truncation_psi', type=float, help='Truncation psi', default=1, show_default=True)
# @click.option('--class', 'class_idx', type=int, help='Class label (unconditional if not specified)')
# @click.option('--noise-mode', help='Noise mode', type=click.Choice(['const', 'random', 'none']), default='const', show_default=True)
# @click.option('--translate', help='Translate XY-coordinate (e.g. \'0.3,1\')', type=parse_vec2, default='0,0', show_default=True, metavar='VEC2')
# @click.option('--rotate', help='Rotation angle in degrees', type=float, default=0, show_default=True, metavar='ANGLE')
# @click.option('--outdir', help='Where to save the output images', type=str, required=True, metavar='DIR')
# def generate_images(
#     network_pkl: str,
#     seeds: List[int],
#     truncation_psi: float,
#     noise_mode: str,
#     outdir: str,
#     translate: Tuple[float,float],
#     rotate: float,
#     class_idx: Optional[int]
# ):
"""Generate images using pretrained network pickle.
Examples:
\b
# Generate an image using pre-trained AFHQv2 model ("Ours" in Figure 1, left).
python gen_images.py --outdir=out --trunc=1 --seeds=2 \\
    --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-afhqv2-512x512.pkl
\b
# Generate uncurated images with truncation using the MetFaces-U dataset
python gen_images.py --outdir=out --trunc=0.7 --seeds=600-605 \\
    --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-t-metfacesu-1024x1024.pkl
"""

# =============== setting params manually instead of with click ==================
# network_pkl = '/content/drive/MyDrive/dev/west-rock/training/00011-stylegan3-r-speed=12x-cut6-1024x1024-gpus1-batch16-gamma50/network-snapshot-000160.pkl'
network_pkl = model_path
class_idx = None
translate = (0,0)
noise_mode = 'const'
rotate = 0
truncation_psi = 1
# ================================================================================

print('Loading networks from "%s"...' % network_pkl)

with dnnlib.util.open_url(network_pkl) as f:
    G = legacy.load_network_pkl(f)['G_ema'].to(device) # type: ignore

# os.makedirs(outdir, exist_ok=True)

# Labels.
label = torch.zeros([1, G.c_dim], device=device)
if G.c_dim != 0:
    if class_idx is None:
        raise click.ClickException('Must specify class label with --class when using a conditional network')
    label[:, class_idx] = 1
else:
    if class_idx is not None:
        print ('warn: --class=lbl ignored when running on an unconditional network')
# Out:
# Loading networks from "/Users/ted/dev/stylegan3/00022-stylegan3-r-240523_01-rose01-YFlips-6min-gpus1-batch8-gamma6.6/network-snapshot-000036.pkl"...

# %%
n_interp_min = 240 # in frames
n_interp_max = 240 # in frames
frame_counter = 0

def lerp(v1,v2,amt):
  diff = v2 - v1
  return v1 + (diff * amt)

with open(os.path.join(outdir,'_log.txt'),'w') as f:
  f.write(f'network_pkl:  {network_pkl}\n')
  f.write(f'n_interp min: {n_interp_min}\n')
  f.write(f'n_interp max: {n_interp_max}\n')
  f.write(f'seeds:        {seeds}\n')

# seeds = seeds[:4]

prev_z = z = torch.from_numpy(np.random.RandomState(seeds[0]).randn(1, G.z_dim)) #.to(device)

for i, seed in enumerate(seeds[1:]):
    # print('Generating image for seed %d (%d/%d) ...' % (seed, seed_idx, len(seeds)))
    curr_z = torch.from_numpy(np.random.RandomState(seed).randn(1, G.z_dim)) #.to(device)

    if n_interp_min < n_interp_max:
      n_interp = np.random.randint(n_interp_min,n_interp_max)
    else:
      n_interp = n_interp_min

    lin_interps = np.linspace(0,1,n_interp,False)
    cos_interps = (np.cos(lin_interps * np.pi) * -0.5) + 0.5

    interps = (lin_interps + cos_interps) * 0.5

    for j, interp_amt in enumerate(interps):

      z = lerp(prev_z,curr_z,interp_amt)
      z = np.array(z)

      # Construct an inverse rotation/translation matrix and pass to the generator.  The
      # generator expects this matrix as an inverse to avoid potentially failing numerical
      # operations in the network.
      if hasattr(G.synthesis, 'input'):
          m = make_transform(translate, rotate)
          m = np.linalg.inv(m)
          G.synthesis.input.transform.copy_(torch.from_numpy(m))

      z = torch.from_numpy(z).to(torch.float32).to(device)
      img = G(z, label, truncation_psi=truncation_psi, noise_mode=noise_mode)
      img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
      PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(os.path.join(outdir,f'{frame_counter:06d}.png'))
      print(f'image {i+1} / {len(seeds)-1} --- interp {j+1} / {len(interps)} --- (frame {frame_counter})')
      frame_counter += 1

    prev_z = curr_z

    # display:
    # plt.axis('off')
    # img = img.reshape((img.shape[1],img.shape[2],img.shape[3]))
    # plt.imshow(img.cpu())
    # plt.show()
# Out:
# image 1 / 15 --- interp 1 / 240 --- (frame 0)
# image 1 / 15 --- interp 2 / 240 --- (frame 1)
# image 1 / 15 --- interp 3 / 240 --- (frame 2)
# image 1 / 15 --- interp 4 / 240 --- (frame 3)
# image 1 / 15 --- interp 5 / 240 --- (frame 4)
# image 1 / 15 --- interp 6 / 240 --- (frame 5)
# image 1 / 15 --- interp 7 / 240 --- (frame 6)
# image 1 / 15 --- interp 8 / 240 --- (frame 7)
# image 1 / 15 --- interp 9 / 240 --- (frame 8)
# image 1 / 15 --- interp 10 / 240 --- (frame 9)
# image 1 / 15 --- interp 11 / 240 --- (frame 10)
# image 1 / 15 --- interp 12 / 240 --- (frame 11)
# image 1 / 15 --- interp 13 / 240 --- (frame 12)
# image 1 / 15 --- interp 14 / 240 --- (frame 13)
# image 1 / 15 --- interp 15 / 240 --- (frame 14)
# image 1 / 15 --- interp 16 / 240 --- (frame 15)
# image 1 / 15 --- interp 17 / 240 --- (frame 16)
# image 1 / 15 --- interp 18 / 240 --- (frame 17)
# image 1 / 15 --- interp 19 / 240 --- (frame 18)
# image 1 / 15 --- interp 20 / 240 --- (frame 19)
# image 1 / 15 --- interp 21 / 240 --- (frame 20)
# image 1 / 15 --- interp 22 / 240 --- (frame 21)
# image 1 / 15 --- interp 23 / 240 --- (frame 22)
# image 1 / 15 --- interp 24 / 240 --- (frame 23)
# image 1 / 15 --- interp 25 / 240 --- (frame 24)
# image 1 / 15 --- interp 26 / 240 --- (frame 25)
# image 1 / 15 --- interp 27 / 240 --- (frame 26)
# image 1 / 15 --- interp 28 / 240 --- (frame 27)
# image 1 / 15 --- interp 29 / 240 --- (frame 28)
# image 1 / 15 --- interp 30 / 240 --- (frame 29)
# image 1 / 15 --- interp 31 / 240 --- (frame 30)
# image 1 / 15 --- interp 32 / 240 --- (frame 31)
# image 1 / 15 --- interp 33 / 240 --- (frame 32)
# image 1 / 15 --- interp 34 / 240 --- (frame 33)
# image 1 / 15 --- interp 35 / 240 --- (frame 34)
# image 1 / 15 --- interp 36 / 240 --- (frame 35)
# image 1 / 15 --- interp 37 / 240 --- (frame 36)
# image 1 / 15 --- interp 38 / 240 --- (frame 37)
# image 1 / 15 --- interp 39 / 240 --- (frame 38)
# image 1 / 15 --- interp 40 / 240 --- (frame 39)
# image 1 / 15 --- interp 41 / 240 --- (frame 40)
# image 1 / 15 --- interp 42 / 240 --- (frame 41)
# image 1 / 15 --- interp 43 / 240 --- (frame 42)
# image 1 / 15 --- interp 44 / 240 --- (frame 43)
# image 1 / 15 --- interp 45 / 240 --- (frame 44)
# image 1 / 15 --- interp 46 / 240 --- (frame 45)
# image 1 / 15 --- interp 47 / 240 --- (frame 46)
# image 1 / 15 --- interp 48 / 240 --- (frame 47)
# image 1 / 15 --- interp 49 / 240 --- (frame 48)
# image 1 / 15 --- interp 50 / 240 --- (frame 49)
# image 1 / 15 --- interp 51 / 240 --- (frame 50)
# image 1 / 15 --- interp 52 / 240 --- (frame 51)
# image 1 / 15 --- interp 53 / 240 --- (frame 52)
# image 1 / 15 --- interp 54 / 240 --- (frame 53)
# image 1 / 15 --- interp 55 / 240 --- (frame 54)
# image 1 / 15 --- interp 56 / 240 --- (frame 55)
# image 1 / 15 --- interp 57 / 240 --- (frame 56)
# image 1 / 15 --- interp 58 / 240 --- (frame 57)
# image 1 / 15 --- interp 59 / 240 --- (frame 58)
# image 1 / 15 --- interp 60 / 240 --- (frame 59)
# image 1 / 15 --- interp 61 / 240 --- (frame 60)
# image 1 / 15 --- interp 62 / 240 --- (frame 61)
# image 1 / 15 --- interp 63 / 240 --- (frame 62)
# image 1 / 15 --- interp 64 / 240 --- (frame 63)
# image 1 / 15 --- interp 65 / 240 --- (frame 64)
# image 1 / 15 --- interp 66 / 240 --- (frame 65)
# image 1 / 15 --- interp 67 / 240 --- (frame 66)
# image 1 / 15 --- interp 68 / 240 --- (frame 67)
# image 1 / 15 --- interp 69 / 240 --- (frame 68)
# image 1 / 15 --- interp 70 / 240 --- (frame 69)
# image 1 / 15 --- interp 71 / 240 --- (frame 70)
# image 1 / 15 --- interp 72 / 240 --- (frame 71)
# image 1 / 15 --- interp 73 / 240 --- (frame 72)
# image 1 / 15 --- interp 74 / 240 --- (frame 73)
# image 1 / 15 --- interp 75 / 240 --- (frame 74)
# image 1 / 15 --- interp 76 / 240 --- (frame 75)
# image 1 / 15 --- interp 77 / 240 --- (frame 76)
# image 1 / 15 --- interp 78 / 240 --- (frame 77)
# image 1 / 15 --- interp 79 / 240 --- (frame 78)
# image 1 / 15 --- interp 80 / 240 --- (frame 79)
# image 1 / 15 --- interp 81 / 240 --- (frame 80)
# image 1 / 15 --- interp 82 / 240 --- (frame 81)
# image 1 / 15 --- interp 83 / 240 --- (frame 82)
# image 1 / 15 --- interp 84 / 240 --- (frame 83)
# image 1 / 15 --- interp 85 / 240 --- (frame 84)
# image 1 / 15 --- interp 86 / 240 --- (frame 85)
# image 1 / 15 --- interp 87 / 240 --- (frame 86)
# image 1 / 15 --- interp 88 / 240 --- (frame 87)
# image 1 / 15 --- interp 89 / 240 --- (frame 88)
# image 1 / 15 --- interp 90 / 240 --- (frame 89)
# image 1 / 15 --- interp 91 / 240 --- (frame 90)
# image 1 / 15 --- interp 92 / 240 --- (frame 91)
# image 1 / 15 --- interp 93 / 240 --- (frame 92)
# image 1 / 15 --- interp 94 / 240 --- (frame 93)
# image 1 / 15 --- interp 95 / 240 --- (frame 94)
# image 1 / 15 --- interp 96 / 240 --- (frame 95)
# image 1 / 15 --- interp 97 / 240 --- (frame 96)
# image 1 / 15 --- interp 98 / 240 --- (frame 97)
# image 1 / 15 --- interp 99 / 240 --- (frame 98)
# image 1 / 15 --- interp 100 / 240 --- (frame 99)
# image 1 / 15 --- interp 101 / 240 --- (frame 100)
# image 1 / 15 --- interp 102 / 240 --- (frame 101)
# image 1 / 15 --- interp 103 / 240 --- (frame 102)
# image 1 / 15 --- interp 104 / 240 --- (frame 103)
# image 1 / 15 --- interp 105 / 240 --- (frame 104)
# image 1 / 15 --- interp 106 / 240 --- (frame 105)
# image 1 / 15 --- interp 107 / 240 --- (frame 106)
# image 1 / 15 --- interp 108 / 240 --- (frame 107)
# image 1 / 15 --- interp 109 / 240 --- (frame 108)
# image 1 / 15 --- interp 110 / 240 --- (frame 109)
# image 1 / 15 --- interp 111 / 240 --- (frame 110)
# image 1 / 15 --- interp 112 / 240 --- (frame 111)
# image 1 / 15 --- interp 113 / 240 --- (frame 112)
# image 1 / 15 --- interp 114 / 240 --- (frame 113)
# image 1 / 15 --- interp 115 / 240 --- (frame 114)
# image 1 / 15 --- interp 116 / 240 --- (frame 115)
# image 1 / 15 --- interp 117 / 240 --- (frame 116)
# image 1 / 15 --- interp 118 / 240 --- (frame 117)
# image 1 / 15 --- interp 119 / 240 --- (frame 118)
# image 1 / 15 --- interp 120 / 240 --- (frame 119)
# image 1 / 15 --- interp 121 / 240 --- (frame 120)
# image 1 / 15 --- interp 122 / 240 --- (frame 121)
# image 1 / 15 --- interp 123 / 240 --- (frame 122)
# image 1 / 15 --- interp 124 / 240 --- (frame 123)
# image 1 / 15 --- interp 125 / 240 --- (frame 124)
# image 1 / 15 --- interp 126 / 240 --- (frame 125)
# image 1 / 15 --- interp 127 / 240 --- (frame 126)
# image 1 / 15 --- interp 128 / 240 --- (frame 127)
# image 1 / 15 --- interp 129 / 240 --- (frame 128)
# image 1 / 15 --- interp 130 / 240 --- (frame 129)
# image 1 / 15 --- interp 131 / 240 --- (frame 130)
# image 1 / 15 --- interp 132 / 240 --- (frame 131)
# image 1 / 15 --- interp 133 / 240 --- (frame 132)
# image 1 / 15 --- interp 134 / 240 --- (frame 133)
# image 1 / 15 --- interp 135 / 240 --- (frame 134)
# image 1 / 15 --- interp 136 / 240 --- (frame 135)
# image 1 / 15 --- interp 137 / 240 --- (frame 136)
# image 1 / 15 --- interp 138 / 240 --- (frame 137)
# image 1 / 15 --- interp 139 / 240 --- (frame 138)
# image 1 / 15 --- interp 140 / 240 --- (frame 139)
# image 15 / 15 --- interp 42 / 240 --- (frame 3401)
# image 15 / 15 --- interp 43 / 240 --- (frame 3402)
# image 15 / 15 --- interp 44 / 240 --- (frame 3403)
# image 15 / 15 --- interp 45 / 240 --- (frame 3404)
# image 15 / 15 --- interp 46 / 240 --- (frame 3405)
# image 15 / 15 --- interp 47 / 240 --- (frame 3406)
# image 15 / 15 --- interp 48 / 240 --- (frame 3407)
# image 15 / 15 --- interp 49 / 240 --- (frame 3408)
# image 15 / 15 --- interp 50 / 240 --- (frame 3409)
# image 15 / 15 --- interp 51 / 240 --- (frame 3410)
# image 15 / 15 --- interp 52 / 240 --- (frame 3411)
# image 15 / 15 --- interp 53 / 240 --- (frame 3412)
# image 15 / 15 --- interp 54 / 240 --- (frame 3413)
# image 15 / 15 --- interp 55 / 240 --- (frame 3414)
# image 15 / 15 --- interp 56 / 240 --- (frame 3415)
# image 15 / 15 --- interp 57 / 240 --- (frame 3416)
# image 15 / 15 --- interp 58 / 240 --- (frame 3417)
# image 15 / 15 --- interp 59 / 240 --- (frame 3418)
# image 15 / 15 --- interp 60 / 240 --- (frame 3419)
# image 15 / 15 --- interp 61 / 240 --- (frame 3420)
# image 15 / 15 --- interp 62 / 240 --- (frame 3421)
# image 15 / 15 --- interp 63 / 240 --- (frame 3422)
# image 15 / 15 --- interp 64 / 240 --- (frame 3423)
# image 15 / 15 --- interp 65 / 240 --- (frame 3424)
# image 15 / 15 --- interp 66 / 240 --- (frame 3425)
# image 15 / 15 --- interp 67 / 240 --- (frame 3426)
# image 15 / 15 --- interp 68 / 240 --- (frame 3427)
# image 15 / 15 --- interp 69 / 240 --- (frame 3428)
# image 15 / 15 --- interp 70 / 240 --- (frame 3429)
# image 15 / 15 --- interp 71 / 240 --- (frame 3430)
# image 15 / 15 --- interp 72 / 240 --- (frame 3431)
# image 15 / 15 --- interp 73 / 240 --- (frame 3432)
# image 15 / 15 --- interp 74 / 240 --- (frame 3433)
# image 15 / 15 --- interp 75 / 240 --- (frame 3434)
# image 15 / 15 --- interp 76 / 240 --- (frame 3435)
# image 15 / 15 --- interp 77 / 240 --- (frame 3436)
# image 15 / 15 --- interp 78 / 240 --- (frame 3437)
# image 15 / 15 --- interp 79 / 240 --- (frame 3438)
# image 15 / 15 --- interp 80 / 240 --- (frame 3439)
# image 15 / 15 --- interp 81 / 240 --- (frame 3440)
# image 15 / 15 --- interp 82 / 240 --- (frame 3441)
# image 15 / 15 --- interp 83 / 240 --- (frame 3442)
# image 15 / 15 --- interp 84 / 240 --- (frame 3443)
# image 15 / 15 --- interp 85 / 240 --- (frame 3444)
# image 15 / 15 --- interp 86 / 240 --- (frame 3445)
# image 15 / 15 --- interp 87 / 240 --- (frame 3446)
# image 15 / 15 --- interp 88 / 240 --- (frame 3447)
# image 15 / 15 --- interp 89 / 240 --- (frame 3448)
# image 15 / 15 --- interp 90 / 240 --- (frame 3449)
# image 15 / 15 --- interp 91 / 240 --- (frame 3450)
# image 15 / 15 --- interp 92 / 240 --- (frame 3451)
# image 15 / 15 --- interp 93 / 240 --- (frame 3452)
# image 15 / 15 --- interp 94 / 240 --- (frame 3453)
# image 15 / 15 --- interp 95 / 240 --- (frame 3454)
# image 15 / 15 --- interp 96 / 240 --- (frame 3455)
# image 15 / 15 --- interp 97 / 240 --- (frame 3456)
# image 15 / 15 --- interp 98 / 240 --- (frame 3457)
# image 15 / 15 --- interp 99 / 240 --- (frame 3458)
# image 15 / 15 --- interp 100 / 240 --- (frame 3459)
# image 15 / 15 --- interp 101 / 240 --- (frame 3460)
# image 15 / 15 --- interp 102 / 240 --- (frame 3461)
# image 15 / 15 --- interp 103 / 240 --- (frame 3462)
# image 15 / 15 --- interp 104 / 240 --- (frame 3463)
# image 15 / 15 --- interp 105 / 240 --- (frame 3464)
# image 15 / 15 --- interp 106 / 240 --- (frame 3465)
# image 15 / 15 --- interp 107 / 240 --- (frame 3466)
# image 15 / 15 --- interp 108 / 240 --- (frame 3467)
# image 15 / 15 --- interp 109 / 240 --- (frame 3468)
# image 15 / 15 --- interp 110 / 240 --- (frame 3469)
# image 15 / 15 --- interp 111 / 240 --- (frame 3470)
# image 15 / 15 --- interp 112 / 240 --- (frame 3471)
# image 15 / 15 --- interp 113 / 240 --- (frame 3472)
# image 15 / 15 --- interp 114 / 240 --- (frame 3473)
# image 15 / 15 --- interp 115 / 240 --- (frame 3474)
# image 15 / 15 --- interp 116 / 240 --- (frame 3475)
# image 15 / 15 --- interp 117 / 240 --- (frame 3476)
# image 15 / 15 --- interp 118 / 240 --- (frame 3477)
# image 15 / 15 --- interp 119 / 240 --- (frame 3478)
# image 15 / 15 --- interp 120 / 240 --- (frame 3479)
# image 15 / 15 --- interp 121 / 240 --- (frame 3480)
# image 15 / 15 --- interp 122 / 240 --- (frame 3481)
# image 15 / 15 --- interp 123 / 240 --- (frame 3482)
# image 15 / 15 --- interp 124 / 240 --- (frame 3483)
# image 15 / 15 --- interp 125 / 240 --- (frame 3484)
# image 15 / 15 --- interp 126 / 240 --- (frame 3485)
# image 15 / 15 --- interp 127 / 240 --- (frame 3486)
# image 15 / 15 --- interp 128 / 240 --- (frame 3487)
# image 15 / 15 --- interp 129 / 240 --- (frame 3488)
# image 15 / 15 --- interp 130 / 240 --- (frame 3489)
# image 15 / 15 --- interp 131 / 240 --- (frame 3490)
# image 15 / 15 --- interp 132 / 240 --- (frame 3491)
# image 15 / 15 --- interp 133 / 240 --- (frame 3492)
# image 15 / 15 --- interp 134 / 240 --- (frame 3493)
# image 15 / 15 --- interp 135 / 240 --- (frame 3494)
# image 15 / 15 --- interp 136 / 240 --- (frame 3495)
# image 15 / 15 --- interp 137 / 240 --- (frame 3496)
# image 15 / 15 --- interp 138 / 240 --- (frame 3497)
# image 15 / 15 --- interp 139 / 240 --- (frame 3498)
# image 15 / 15 --- interp 140 / 240 --- (frame 3499)
# image 15 / 15 --- interp 141 / 240 --- (frame 3500)
# image 15 / 15 --- interp 142 / 240 --- (frame 3501)
# image 15 / 15 --- interp 143 / 240 --- (frame 3502)
# image 15 / 15 --- interp 194 / 240 --- (frame 3553)
# image 15 / 15 --- interp 195 / 240 --- (frame 3554)
# image 15 / 15 --- interp 196 / 240 --- (frame 3555)
# image 15 / 15 --- interp 197 / 240 --- (frame 3556)
# image 15 / 15 --- interp 198 / 240 --- (frame 3557)
# image 15 / 15 --- interp 199 / 240 --- (frame 3558)
# image 15 / 15 --- interp 200 / 240 --- (frame 3559)
# image 15 / 15 --- interp 201 / 240 --- (frame 3560)
# image 15 / 15 --- interp 202 / 240 --- (frame 3561)
# image 15 / 15 --- interp 203 / 240 --- (frame 3562)
# image 15 / 15 --- interp 204 / 240 --- (frame 3563)
# image 15 / 15 --- interp 205 / 240 --- (frame 3564)
# image 15 / 15 --- interp 206 / 240 --- (frame 3565)
# image 15 / 15 --- interp 207 / 240 --- (frame 3566)
# image 15 / 15 --- interp 208 / 240 --- (frame 3567)
# image 15 / 15 --- interp 209 / 240 --- (frame 3568)
# image 15 / 15 --- interp 210 / 240 --- (frame 3569)
# image 15 / 15 --- interp 211 / 240 --- (frame 3570)
# image 15 / 15 --- interp 212 / 240 --- (frame 3571)
# image 15 / 15 --- interp 213 / 240 --- (frame 3572)
# image 15 / 15 --- interp 214 / 240 --- (frame 3573)
# image 15 / 15 --- interp 215 / 240 --- (frame 3574)
# image 15 / 15 --- interp 216 / 240 --- (frame 3575)
# image 15 / 15 --- interp 217 / 240 --- (frame 3576)
# image 15 / 15 --- interp 218 / 240 --- (frame 3577)
# image 15 / 15 --- interp 219 / 240 --- (frame 3578)
# image 15 / 15 --- interp 220 / 240 --- (frame 3579)
# image 15 / 15 --- interp 221 / 240 --- (frame 3580)
# image 15 / 15 --- interp 222 / 240 --- (frame 3581)
# image 15 / 15 --- interp 223 / 240 --- (frame 3582)
# image 15 / 15 --- interp 224 / 240 --- (frame 3583)
# image 15 / 15 --- interp 225 / 240 --- (frame 3584)
# image 15 / 15 --- interp 226 / 240 --- (frame 3585)
# image 15 / 15 --- interp 227 / 240 --- (frame 3586)
# image 15 / 15 --- interp 228 / 240 --- (frame 3587)
# image 15 / 15 --- interp 229 / 240 --- (frame 3588)
# image 15 / 15 --- interp 230 / 240 --- (frame 3589)
# image 15 / 15 --- interp 231 / 240 --- (frame 3590)
# image 15 / 15 --- interp 232 / 240 --- (frame 3591)
# image 15 / 15 --- interp 233 / 240 --- (frame 3592)
# image 15 / 15 --- interp 234 / 240 --- (frame 3593)
# image 15 / 15 --- interp 235 / 240 --- (frame 3594)
# image 15 / 15 --- interp 236 / 240 --- (frame 3595)
# image 15 / 15 --- interp 237 / 240 --- (frame 3596)
# image 15 / 15 --- interp 238 / 240 --- (frame 3597)
# image 15 / 15 --- interp 239 / 240 --- (frame 3598)
# image 15 / 15 --- interp 240 / 240 --- (frame 3599)

# %%
import os
filename = Path(outdir).stem
# print(filename)
command = f'ffmpeg -r 30 -i "{outdir}/%06d.png" -c:v libx264 -pix_fmt yuv420p "{outdir}/../{filename}.mp4"'
print(command)
os.system(command)
# Out:
# ffmpeg -r 30 -i "/Volumes/2024-May-Ted-Moore/videos/rose/stylegan/240525_02-rose01-blobs-interpolated-cos-pkl=36/%06d.png" -c:v libx264 -pix_fmt yuv420p "/Volumes/2024-May-Ted-Moore/videos/rose/stylegan/240525_02-rose01-blobs-interpolated-cos-pkl=36/../240525_02-rose01-blobs-interpolated-cos-pkl=36.mp4"
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, image2, from '/Volumes/2024-May-Ted-Moore/videos/rose/stylegan/240525_02-rose01-blobs-interpolated-cos-pkl=36/%06d.png':
#   Duration: 00:02:24.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown), 1024x1024, 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12a708a00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12a708a00] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x12a708a00] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Volumes/2024-May-Ted-Moore/videos/rose/stylegan/240525_02-rose01-blobs-interpolated-cos-pkl=36/../240525_02-rose01-blobs-interpolated-cos-pkl=36.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024, q=2-31, 30 fps, 15360 tbn
#       Metadata:
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x12a706aa0] video:21085KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.205025%
# frame= 3600 fps=209 q=-1.0 Lsize=   21128KiB time=00:01:59.93 bitrate=1443.2kbits/s speed=6.95x
# [libx264 @ 0x12a708a00] frame I:15    Avg QP:17.76  size: 67575
# [libx264 @ 0x12a708a00] frame P:911   Avg QP:20.93  size: 14454
# [libx264 @ 0x12a708a00] frame B:2674  Avg QP:24.56  size:  2771
# [libx264 @ 0x12a708a00] consecutive B-frames:  0.7%  0.4%  0.8% 98.0%
# [libx264 @ 0x12a708a00] mb I  I16..4: 12.7% 53.3% 34.0%
# [libx264 @ 0x12a708a00] mb P  I16..4:  3.3%  8.2%  0.8%  P16..4: 36.8% 16.0%  5.4%  0.0%  0.0%    skip:29.4%
# [libx264 @ 0x12a708a00] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 37.8%  2.8%  0.1%  direct: 0.3%  skip:58.7%  L0:40.8% L1:53.6% BI: 5.6%
# [libx264 @ 0x12a708a00] 8x8 transform intra:64.6% inter:73.8%
# [libx264 @ 0x12a708a00] coded y,uvDC,uvAC intra: 19.2% 42.2% 15.9% inter: 4.1% 7.4% 1.8%
# [libx264 @ 0x12a708a00] i16 v,h,dc,p: 31% 29% 10% 30%
# [libx264 @ 0x12a708a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 12% 54%  3%  5%  3%  4%  3%  3%
# [libx264 @ 0x12a708a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 23% 29%  5%  6%  4%  5%  3%  3%
# [libx264 @ 0x12a708a00] i8c dc,h,v,p: 61% 20% 17%  3%
# [libx264 @ 0x12a708a00] Weighted P-Frames: Y:1.9% UV:0.0%
# [libx264 @ 0x12a708a00] ref P L0: 65.0%  8.9% 18.7%  7.3%  0.1%
# [libx264 @ 0x12a708a00] ref B L0: 90.9%  7.6%  1.5%
# [libx264 @ 0x12a708a00] ref B L1: 95.4%  4.6%
# [libx264 @ 0x12a708a00] kb/s:1439.35
# 0
